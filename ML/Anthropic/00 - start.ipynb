# %%
import boto3

# %% [markdown]
# ## Credentials
#
# Go to bedrock & retrieve a short-term API key. If using Jupyter, execute the following statement **before** starting jupyter (replace with correct API key!
#
# `
# export AWS_BEARER_TOKEN_BEDROCK=bedrock-api-key-YmVkcm9jay5hbWF6b25...
# `
#
# ## Model Selection
#
# I took the modelId from a bedrock tutorial & it seems that this is the only one working... In addition, I have to use the `us-east-1` region... Other regions do not work. I have no idea why => TODO

# %%
modelId = "us.anthropic.claude-haiku-4-5-20251001-v1:0"

# modelId = "eu.anthropic.claude-haiku-4-5-20251001-v1:0"

# %%
user_message = { 
            "role": "user", 
            "content": [{"text": "Write a one-sentence bedtime story about a unicorn."}]
        }

# %%
client = boto3.client("bedrock-runtime", region_name="us-east-1")

# %%
response = client.converse(modelId=modelId, messages=[user_message])
print(response)
# Out:
# {'ResponseMetadata': {'RequestId': '03e85225-6b6a-45b8-8bee-b7aa660d828c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 09 Mar 2026 16:11:52 GMT', 'content-type': 'application/json', 'content-length': '547', 'connection': 'keep-alive', 'x-amzn-requestid': '03e85225-6b6a-45b8-8bee-b7aa660d828c'}, 'RetryAttempts': 0}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '# The Sleepy Unicorn\n\nAs the silver moon rose over the enchanted forest, a gentle unicorn with a shimmering mane nestled into a bed of soft moss and starlight, dreaming of galloping through meadows of rainbow flowers until the dawn.'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 20, 'outputTokens': 61, 'totalTokens': 81, 'cacheReadInputTokens': 0, 'cacheWriteInputTokens': 0}, 'metrics': {'latencyMs': 1496}}

# %%
print(response["output"]["message"]["content"][0]["text"])
# Out:
# # The Sleepy Unicorn
#
# As the silver moon rose over the enchanted forest, a gentle unicorn with a shimmering mane nestled into a bed of soft moss and starlight, dreaming of galloping through meadows of rainbow flowers until the dawn.
