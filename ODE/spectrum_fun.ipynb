# %%
# %run util.py

# %%
n = 1_00
a_1, f_1 = 1.0, 0.1
a_2, f_2 = 0., 0.4

# %%
t = np.arange(n)

# %%
x = a_1 * np.sqrt(2)*np.sin(2*np.pi*f_1*t) + a_2 * np.sqrt(2)*np.sin(2*np.pi*f_2*t)

# %%
plotSpec(x)

# %%
plt.plot(x)
