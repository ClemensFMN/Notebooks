# %%
# %run util.py

# %%
def dX_dt(X, t=0):
    return np.array([             1.0*X[1] ,
                    X[0] - X[0]**3        ])

# %%
vField(-2, 2, -2, 2, dX_dt, Norm = True)

# %%
tstop = 10
X, infodict = solveODE(dX_dt, [1., 1.2], 0, tstop)
y1, y2 = X.T
infodict['message']
# Out:
# 'Integration successful.'

# %%
t  = np.linspace(0, tstop, 1000)

plt.plot(t, y1, 'r-', label='$y_1$')
plt.plot(t, y2  , 'b-', label='$y_2$')
plt.grid()
plt.legend(loc='best')
plt.xlabel('time')
plt.ylabel('$y_1, y_2$')
# Out:
# Text(0, 0.5, '$y_1, y_2$')

# %%
plt.plot(y1, y2)
plt.grid()
plt.legend(loc='best')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
