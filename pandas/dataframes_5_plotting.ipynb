# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %%
ts = pd.Series(np.random.randn(100), index=pd.date_range("1/1/2000", periods=100))
ts.plot()
# Out:
# <Axes: >

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df2.plot.bar();

# %%
df4 = pd.DataFrame(
    {
        "a": np.random.randn(10000) + 3,
        "b": np.random.randn(10000),
        "c": np.random.randn(10000) - 4,
    },
    columns=["a", "b", "c"],
)

df4.plot.hist(bins=20, alpha=0.4);

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df.describe()
# Out:
#                a          b          c          d
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.413559   0.427847   0.491228   0.541847
# std     0.262622   0.230074   0.277133   0.375794
# min     0.015734   0.098199   0.062968   0.008076
# 25%     0.245257   0.289696   0.325795   0.264663
# 50%     0.376379   0.382907   0.522983   0.578860
# 75%     0.570950   0.540128   0.622725   0.892371
# max     0.926044   0.875268   0.952962   0.982776

# %%
df.plot.scatter(x="a", y="b", s=50);

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])
df.plot.box();
